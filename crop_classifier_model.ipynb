# %%
try:
  # %tensorflow_version 1.x
except Exception:
  pass
import tensorflow as tf
assert tf.__version__.startswith('1')

tf.enable_eager_execution()

import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# TensorFlow 1.x selected.

# %%
# !unzip '/content/train.zip'
# !unzip '/content/new.zip'
# !unzip '/content/dataset.zip'
# !unzip '/content/crop.zip'
# Out:
# Archive:  /content/train.zip
#    creating: data/bajra/
#   inflating: data/bajra/1511340347-4701.jpg
#   inflating: data/bajra/1583912022_Jowar_big_2.jpg
#   inflating: data/bajra/2aa98bcad23f92a695505239de73d941.jpg
#   inflating: data/bajra/49ba5b2c0360ba0658fdacd4e94b6ec4.jpg
#   inflating: data/bajra/5000-hybrid-pioneer-86m11-bajra-seeds-pearl-millet-seeds-1-5kg-original-imaft7xedxesp9aa.jpeg
#   inflating: data/bajra/5000-trimurti-tmbh-2652-bajra-seeds-pearl-millet-seeds-1-5kg-original-imaft8gvykbfke5n.jpeg
#   inflating: data/bajra/531f61_42baae386ec44ea7bdda77804c5feefemv2_d_2992_2000_s_2.jpg
#   inflating: data/bajra/853476-bajra-072919.jpg
#   inflating: data/bajra/8b9f17943f53dab4aa225b9235552ab2.jpg
#   inflating: data/bajra/bajra.jpg
#   inflating: data/bajra/bajra0.jpg
#   inflating: data/bajra/bajra21.jpg
#   inflating: data/bajra/Bajra-Cultivation.jpg
#   inflating: data/bajra/bajra-millet-DFYWMR.jpg
# ...

# %%
import numpy as np
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img 
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import os
import cv2

datagen = ImageDataGenerator(rotation_range =60, 
                     width_shift_range = 0.2, 
                     height_shift_range = 0.2,  
                     rescale=1./255, 
                     shear_range=0.4, 
                     zoom_range=[0.5,1.0], 
                     horizontal_flip = True,vertical_flip= True,                
                     fill_mode = 'nearest', 
                     data_format='channels_last') 

imgs = os.listdir(r'/content/data/bajra')

for img in imgs:
    img=cv2.imread(r'/content/data/bajra'+"/"+img)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow (x, batch_size=1, save_to_dir =r'/content/dataset/bajra', save_prefix ='bajra_data', save_format='jpg'):
        i+=1
        if i>13:
            break
# Out:
# Using TensorFlow backend.

# %%
datagen = ImageDataGenerator(rotation_range =60, 
                     width_shift_range = 0.2, 
                     height_shift_range = 0.2,  
                     rescale=1./255, 
                     shear_range=0.4, 
                     zoom_range=[0.5,1.0], 
                     horizontal_flip = True,vertical_flip= True,                
                     fill_mode = 'nearest', 
                     data_format='channels_last') 

imgs = os.listdir(r'/content/data/corn')

for img in imgs:
    img=cv2.imread(r'/content/data/corn'+"/"+img)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow (x, batch_size=1, save_to_dir =r'/content/dataset/corn', save_prefix ='corn_data', save_format='jpg'):
        i+=1
        if i>13:
            break

# %%
# !unzip '/content/new.zip'
# Out:
# Archive:  /content/new.zip
#    creating: new/bitter gourd/
#   inflating: new/bitter gourd/020714goya1.jpg
#   inflating: new/bitter gourd/4c52ec14e5e189a0d6b6b08f1116b686.jpg
#   inflating: new/bitter gourd/51Ty8c4Ue6L.jpg
#   inflating: new/bitter gourd/51yVVdOdVsL._SX425_.jpg
#   inflating: new/bitter gourd/61gjLaHE4SL._AC_UL600_SR600600_.jpg
#   inflating: new/bitter gourd/71o5MjHGK7L._SX466_.jpg
#   inflating: new/bitter gourd/87009c49c1ea74191f882f48991d8259.jpg
#   inflating: new/bitter gourd/a85614fa165e046ec066961310327105.jpg
#   inflating: new/bitter gourd/bitter.jpg
#   inflating: new/bitter gourd/bitter0.jpg
#   inflating: new/bitter gourd/bitter20g.jpg
#   inflating: new/bitter gourd/BitterGourd .jpg
#   inflating: new/bitter gourd/bittergourd.jpg
#   inflating: new/bitter gourd/Bitter-gourd-300x278.jpg
#   inflating: new/bitter gourd/bitter-gourd-4345074_960_720.jpg
#   inflating: new/bitter gourd/bitter-gourd-4345077_640.jpg
# ...

# %%
# !ls /content/dataset/cabbage/

# %%
l=["bitter_gourd","cabbage"]
for i in range(2):
  datagen = ImageDataGenerator(rotation_range =60, 
                     width_shift_range = 0.2, 
                     height_shift_range = 0.2,  
                     rescale=1./255, 
                     shear_range=0.4, 
                     zoom_range=[0.5,1.0], 
                     horizontal_flip = True,vertical_flip= True,                
                     fill_mode = 'nearest', 
                     data_format='channels_last') 
  dir="/content/new/"+l[i]
  imgs = os.listdir(dir)
  save_dir='/content/dataset/'+l[i]
  prefix=l[i]+"_data"

  for img in imgs:
      img=cv2.imread(dir+"/"+img)
      x = img_to_array(img)
      x = x.reshape((1,) + x.shape)

      i = 0
      for batch in datagen.flow (x, batch_size=1, save_to_dir =save_dir, save_prefix =prefix, save_format='jpg'):
          i+=1
          if i>13:
              break

# %%
# !ls /content/dataset/orange/

# %%
l=["orange","ragi","sorghum"]
for i in range(len(l)):
  datagen = ImageDataGenerator(rotation_range =60, 
                     width_shift_range = 0.2, 
                     height_shift_range = 0.2,  
                     rescale=1./255, 
                     shear_range=0.4, 
                     zoom_range=[0.5,1.0], 
                     horizontal_flip = True,vertical_flip= True,                
                     fill_mode = 'nearest', 
                     data_format='channels_last') 
  dir="/content/crop/"+l[i]
  imgs = os.listdir(dir)
  save_dir='/content/dataset/'+l[i]
  prefix=l[i]+"_data"

  for img in imgs:
      img=cv2.imread(dir+"/"+img)
      x = img_to_array(img)
      x = x.reshape((1,) + x.shape)

      i = 0
      for batch in datagen.flow (x, batch_size=1, save_to_dir =save_dir, save_prefix =prefix, save_format='jpg'):
          i+=1
          if i>13:
              break

# %%
# !ls /content/dataset/rice/

# %%
l1=["cotton","jute","rice","sugarcane","sunflower","tea","tobacco","wheat"]
for i in range(len(l1)):
  datagen = ImageDataGenerator(rotation_range =60, 
                     width_shift_range = 0.2, 
                     height_shift_range = 0.2,  
                     rescale=1./255, 
                     shear_range=0.4, 
                     zoom_range=[0.5,1.0], 
                     horizontal_flip = True,vertical_flip= True,                
                     fill_mode = 'nearest', 
                     data_format='channels_last') 
  dir="/content/data/"+l1[i]
  imgs = os.listdir(dir)
  save_dir='/content/dataset/'+l1[i]
  prefix=l1[i]+"_data"

  for img in imgs:
      img=cv2.imread(dir+"/"+img)
      x = img_to_array(img)
      x = x.reshape((1,) + x.shape)

      i = 0
      for batch in datagen.flow (x, batch_size=1, save_to_dir =save_dir, save_prefix =prefix, save_format='jpg'):
          i+=1
          if i>13:
              break
